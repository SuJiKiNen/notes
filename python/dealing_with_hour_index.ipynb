# %%
import pandas as pd
import numpy as np

# %%
index = pd.date_range("2018-1-1", "2018-12-1", freq="D")

# %%
len(index)
# Out:
# 335

# %%
df = pd.DataFrame(np.random.randn(len(index)), index=index)

# %%
df
# Out:
#                    0
# 2018-01-01 -1.098453
# 2018-01-02  0.575747
# 2018-01-03 -0.614734
# 2018-01-04  1.211989
# 2018-01-05  0.657960
# 2018-01-06  0.810979
# 2018-01-07 -1.471030
# 2018-01-08  0.081714
# 2018-01-09  0.273029
# 2018-01-10 -1.049299
# 2018-01-11 -0.765382
# 2018-01-12 -1.472283
# 2018-01-13  0.307229
# 2018-01-14 -1.653776
# 2018-01-15 -0.099723
# 2018-01-16  0.145214
# 2018-01-17 -0.033725
# 2018-01-18  0.514284
# 2018-01-19  0.715389
# 2018-01-20  1.277362
# 2018-01-21  0.660934
# 2018-01-22 -0.355341
# 2018-01-23  0.088582
# 2018-01-24  0.701588
# 2018-01-25 -1.087933
# 2018-01-26 -0.877279
# 2018-01-27  0.326665
# 2018-01-28 -0.347926
# 2018-01-29  1.673731
# 2018-01-30  0.796353
# ...              ...
# 2018-11-02 -1.608467
# 2018-11-03  1.119804
# 2018-11-04  0.599280
# 2018-11-05 -0.969710
# 2018-11-06 -0.153879
# 2018-11-07  0.317790
# 2018-11-08  0.812963
# 2018-11-09  0.127139
# 2018-11-10  0.348411
# 2018-11-11  0.580891
# 2018-11-12 -1.300217
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#          index         0
# 0   2018-01-01 -1.098453
# 1   2018-01-02  0.575747
# 2   2018-01-03 -0.614734
# 3   2018-01-04  1.211989
# 4   2018-01-05  0.657960
# 5   2018-01-06  0.810979
# 6   2018-01-07 -1.471030
# 7   2018-01-08  0.081714
# 8   2018-01-09  0.273029
# 9   2018-01-10 -1.049299
# 10  2018-01-11 -0.765382
# 11  2018-01-12 -1.472283
# 12  2018-01-13  0.307229
# 13  2018-01-14 -1.653776
# 14  2018-01-15 -0.099723
# 15  2018-01-16  0.145214
# 16  2018-01-17 -0.033725
# 17  2018-01-18  0.514284
# 18  2018-01-19  0.715389
# 19  2018-01-20  1.277362
# 20  2018-01-21  0.660934
# 21  2018-01-22 -0.355341
# 22  2018-01-23  0.088582
# 23  2018-01-24  0.701588
# 24  2018-01-25 -1.087933
# 25  2018-01-26 -0.877279
# 26  2018-01-27  0.326665
# 27  2018-01-28 -0.347926
# 28  2018-01-29  1.673731
# 29  2018-01-30  0.796353
# ..         ...       ...
# 305 2018-11-02 -1.608467
# 306 2018-11-03  1.119804
# 307 2018-11-04  0.599280
# 308 2018-11-05 -0.969710
# 309 2018-11-06 -0.153879
# ...

# %%
# %timeit -n 1000 pd.to_datetime(df['index'], unit='h').dt.strftime("%H:%M")
# Out:
# 2.07 ms ± 28.2 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %timeit -n 1000 df['index'].astype(np.str).str.pad(width=2, side='left', fillchar='0') + ':00'
# Out:
# 2.09 ms ± 38.5 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)
